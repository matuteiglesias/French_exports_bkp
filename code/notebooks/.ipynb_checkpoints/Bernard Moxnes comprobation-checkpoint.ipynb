# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
countries = pd.read_csv('./../../data/c_table.csv')[['Country or area', 'ISO3166-1-Alpha-2']]
name_mapper = countries.set_index('ISO3166-1-Alpha-2').to_dict()['Country or area']
name_mapper['US'] ='United States'; name_mapper['GB']='United Kingdom'

# %%
###

# Bernard and moxnes
# Firm sales/number of buyers

# Pareto by country for hypothesis on G/g

# %%
df = pd.read_csv('./../../data/processed/_FBCP.csv')

firm_sizes = df.groupby(['IMPORT', 'ID', 'PERIOD'])['VART'].sum().reset_index()
df = df.merge(firm_sizes, on = ['IMPORT', 'PERIOD', 'ID'])
df['log_size'] = np.log10(df.VART_y)
# Keep exports
df = df.loc[df.IMPORT == 0].drop('IMPORT', axis = 1)

# %%
# Aggregate products out:
df = df.groupby(['ID','PYOD','VAT','PERIOD'])['VART'].sum().reset_index()

# %%
df.head()
# Out:
#    ID PYOD VAT  PERIOD     VART
# 0   0   BR  BR       2   1582.0
# 1   0   CA  CA       2  83457.0
# 2   0   CH  CH       2   1616.0
# 3   0   CM  CM       2   6560.0
# 4   0   CN  CN       2   3684.0

# %%
k1_fij = pd.DataFrame(df.groupby(['PYOD', 'PERIOD'])['VART'].sum()/df.groupby(['PYOD', 'PERIOD'])['VAT'].nunique(),
                      columns = ['k1_fFRj']).reset_index()

# %%
k1_fij['Country'] = k1_fij['PYOD'].map(name_mapper).fillna('_Others')

# %%
k1_fij.sample(60).sort_values(by = 'k1_fFRj')
# Out:
#     PYOD  PERIOD       k1_fFRj                                     Country
# 210   TV       2  7.600000e+01                                      Tuvalu
# 70    FK       2  5.875000e+03                 Falkland Islands (Malvinas)
# 109   KI       2  2.155000e+04                                    Kiribati
# 155   NR       2  5.616400e+04                                       Nauru
# 140   MS       2  1.292155e+05                                  Montserrat
# 178   SB       2  1.789435e+05                             Solomon Islands
# 124   LT       2  1.855109e+05                                   Lithuania
# 58    DK       2  2.614292e+05                                     Denmark
# 184   SI       2  2.838399e+05                                    Slovenia
# 102   IT       2  3.340872e+05                                       Italy
# 71    FM       2  3.468530e+05            Micronesia (Federated States of)
# 84    GS       2  3.778270e+05                                     _Others
# 204   TL       2  4.255135e+05                                 Timor-Leste
# 141   MT       2  5.428156e+05                                       Malta
# 74    GB       2  6.530892e+05                              United Kingdom
# 111   KN       2  1.801734e+06                       Saint Kitts and Nevis
# 112   KP       2  2.310297e+06       Democratic People's Republic of Korea
# 32    BT       2  2.458256e+06                                      Bhutan
# 75    GD       2  3.333532e+06                                     Grenada
# 138   MP       2  4.278871e+06                    Northern Mariana Islands
# 52    CW       2  9.014765e+06                                     Curaçao
# 88    GY       2  1.385993e+07                                      Guyana
# 151   NI       2  1.424675e+07                                   Nicaragua
# 27    BN       2  1.907430e+07                           Brunei Darussalam
# 228   XC       2  2.505930e+07                                     _Others
# 17    BB       2  2.924003e+07                                    Barbados
# 120   LI       2  2.950520e+07                               Liechtenstein
# 222   VG       2  4.018166e+07                      British Virgin Islands
# 136   MN       2  4.404701e+07                                    Mongolia
# 92    HT       2  5.607065e+07                                       Haiti
# 130   ME       2  6.070240e+07                                  Montenegro
# 135   MM       2  6.275673e+07                                     Myanmar
# 115   KY       2  6.584927e+07                              Cayman Islands
# 180   SD       2  1.115335e+08                                       Sudan
# 198   TD       2  1.731993e+08                                        Chad
# 137   MO       2  1.745895e+08  China, Macao Special Administrative Region
# 82    GQ       2  1.800061e+08                           Equatorial Guinea
# 81    GN       2  2.047433e+08                                      Guinea
# 195   SY       2  2.484136e+08                        Syrian Arab Republic
# 217   UY       2  2.493715e+08                                     Uruguay
# 0     AD       2  2.875959e+08                                     Andorra
# 159   PE       2  2.926000e+08                                        Peru
# 139   MR       2  3.310190e+08                                  Mauritania
# 15    AZ       2  3.363234e+08                                  Azerbaijan
# 134   ML       2  3.923944e+08                                        Mali
# 131   MG       2  3.973671e+08                                  Madagascar
# 104   JO       2  4.936075e+08                                      Jordan
# 160   PF       2  5.803030e+08                            French Polynesia
# 46    CM       2  8.831413e+08                                    Cameroon
# 171   QA       2  9.273618e+08                                       Qatar
# 45    CL       2  9.876100e+08                                       Chile
# 73    GA       2  1.046171e+09                                       Gabon
# 188   SN       2  1.119259e+09                                     Senegal
# 234   ZA       2  2.313230e+09                                South Africa
# 177   SA       2  4.063219e+09                                Saudi Arabia
# 206   TN       2  4.483975e+09                                     Tunisia
# 1     AE       2  5.555688e+09                        United Arab Emirates
# 182   SG       2  7.523659e+09                                   Singapore
# 105   JP       2  8.934725e+09                                       Japan
# 47    CN       2  1.808417e+10                                       China

# %%
plt.hist(np.log10(k1_fij), 14)
plt.show()

# %% [markdown]
# ## Buyer and seller pareto fits

# %%
seller_size = df.groupby(['PYOD', 'PERIOD', 'ID'])[['VART']].sum()
buyer_size = df.groupby(['PYOD', 'PERIOD', 'VAT'])[['VART']].sum()

# %%
seller_TOTsize = df.groupby(['PERIOD', 'ID'])[['VART']].sum()
seller_TOTsize
# Out:
#                           VART
# PERIOD ID
# 2      0          1.446590e+05
#        330        1.126415e+05
#        355        6.391765e+05
#        413        8.207196e+06
#        447        6.660000e+03
#        546        2.710431e+06
#        553        1.287150e+04
#        678        2.615805e+05
#        694        1.169151e+06
#        728        1.893000e+03
#        793        3.404639e+07
#        801        6.513450e+04
#        835        6.553968e+06
#        884        2.740240e+05
#        926        9.292950e+04
#        942        6.967000e+05
#        1072       1.541630e+05
#        1197       5.206480e+05
#        1213       1.215500e+03
#        2120       5.020400e+04
#        2807       3.715000e+03
#        2823       2.997000e+03
#        2880       2.032274e+06
#        2906       2.777150e+05
#        2922       8.064000e+03
#        2930       4.178350e+05
#        2955       4.974600e+04
#        2971       2.466059e+07
#        2989       1.970450e+04
#        2997       1.184850e+06
# ...                        ...
#        998125314  2.122134e+06
#        998155816  1.011808e+06
#        998175616  2.725000e+03
#        998229314  4.620000e+03
#        998229702  7.156950e+04
#        998239123  9.019255e+05
#        998259519  1.620000e+04
#        998269211  5.602165e+07
#        998299804  5.294200e+06
#        998308217  5.000000e+03
#        998318018  2.836812e+06
#        998318810  9.709450e+04
#        998328215  4.380035e+05
#        998348601  2.619395e+05
#        998358204  1.481670e+05
#        998417125  3.000000e+04
#        998447411  1.486705e+07
#        998457311  5.500000e+02
#        998457808  8.741030e+06
#        998477905  2.895000e+03
#        998600704  1.302850e+05
#        998610109  1.431350e+05
#        998610810  9.125000e+02
#        998620421  9.632880e+05
#        998813703  4.000000e+02
#        998823504  3.010000e+03
#        999990005  7.879350e+04
#        999990401  2.775111e+06
#        999999998  2.246800e+04
#        999999999  1.765523e+09
#
# [123453 rows x 1 columns]

# %%
EU_ctries = df.groupby('PYOD')['VAT'].nunique().sort_values().tail(33).index

# %%
x = np.arange(3, 8, .2)

fig, axs = plt.subplots(1, 2, figsize = (16, 5))


# Line of the total
sizes = seller_TOTsize
sizes = pd.DataFrame(np.log10(sizes.loc[2])).rename(columns = {'VART': 'log_size'})

cdf = []
for th in x:
    cdf += [1 - (sizes > th).sum()/len(sizes)]
cdf = np.array(cdf).flatten()
y = np.log10(1 - cdf)
ax = axs[0]
ax.plot(x, y, color = 'k')

for i in range(2):
    ax = axs[i]
    for ctry in EU_ctries:
        sizes = [seller_size, buyer_size][i]
        sizes = pd.DataFrame(np.log10(sizes.loc[ctry].loc[2])).rename(columns = {'VART': 'log_size'})

        cdf = []
        for th in x:
            cdf += [1 - (sizes > th).sum()/len(sizes)]
        cdf = np.array(cdf).flatten()

        # For what matters, we could just fit a linear in the upper 90% of firms and drop the SMEs. The we would have a pareto/zipf
        y = np.log10(1 - cdf)

        ax.plot(x, y, label = ctry, linestyle = '-', lw = .75)

        ax.set_ylim(-4, 0)
        ax.set_xlim(3, 8)
        ax.set_xlabel('Exporter size (log)', fontsize = 13)
        ax.set_ylabel('log(1 - CDF)', fontsize = 13)
        ax.legend(loc = (.1, .1))

        # plt.savefig('./../../../thesis_writing/figures/pareto_option.png', dpi = 400)
plt.show()

# %% [markdown]
# ## Bernard Margins

# %%
df = pd.read_csv('./../../data/processed/_FBCP.csv')

firm_sizes = df.groupby(['IMPORT', 'ID', 'PERIOD'])['VART'].sum().reset_index()
df = df.merge(firm_sizes, on = ['IMPORT', 'PERIOD', 'ID'])
df['log_size'] = np.log10(df.VART_y)
# Keep exports
df = df.loc[df.IMPORT == 0].drop('IMPORT', axis = 1)

# %%
grouped = df.groupby(['ID', 'PERIOD'])

n_prods = grouped['CN ID 4'].nunique()
n_vats = grouped['VAT'].nunique()
n_cases = grouped.count().log_size

# %%
data = grouped.first().drop(['CN ID 4','PYOD','VAT','VART_x'], axis = 1)

# %%
data['n_prods'] = n_prods
data['n_vats'] = n_vats
data['n_cases'] = n_cases

data['density'] = n_cases/(n_prods*n_vats)
data['x_mean'] = data.VART_y/n_cases
