# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
countries = pd.read_csv('./../../data/c_table.csv')[['Country or area', 'ISO3166-1-Alpha-2']]
name_mapper = countries.set_index('ISO3166-1-Alpha-2').to_dict()['Country or area']
name_mapper['US'] ='United States'; name_mapper['GB']='United Kingdom'

# %%
###

# Bernard and moxnes
# Firm sales/number of buyers

# Pareto by country for hypothesis on G/g

# %%
df = pd.read_csv('./../../data/processed/_FBCP.csv')

firm_sizes = df.groupby(['IMPORT', 'ID', 'PERIOD'])['VART'].sum().reset_index()
df = df.merge(firm_sizes, on = ['IMPORT', 'PERIOD', 'ID'])
df['log_size'] = np.log10(df.VART_y)
# Keep exports
df = df.loc[df.IMPORT == 0].drop('IMPORT', axis = 1)

# %%
# Aggregate products out:
df = df.groupby(['ID','PYOD','VAT','PERIOD'])['VART_x'].sum().reset_index()

# %%
df.head()
# Out:
#    ID PYOD VAT  PERIOD   VART_x
# 0   0   BR  BR       2   1582.0
# 1   0   CA  CA       2  83457.0
# 2   0   CH  CH       2   1616.0
# 3   0   CM  CM       2   6560.0
# 4   0   CN  CN       2   3684.0

# %%
k1_fij = pd.DataFrame(df.groupby(['PYOD', 'PERIOD'])['VART_x'].sum()/df.groupby(['PYOD', 'PERIOD'])['VAT'].nunique(),
                      columns = ['k1_fFRj']).reset_index()

# %%
k1_fij['Country'] = k1_fij['PYOD'].map(name_mapper).fillna('_Others')

# %%
k1_fij.sample(60).sort_values(by = 'k1_fFRj')
# Out:
#     PYOD  PERIOD       k1_fFRj                                         Country
# 51    CX       2  8.709500e+04                                         _Others
# 20    BG       2  2.696696e+05                                        Bulgaria
# 69    FM       2  3.483620e+05                Micronesia (Federated States of)
# 52    CY       2  3.879476e+05                                          Cyprus
# 171   RO       2  5.766890e+05                                         Romania
# 228   XU       2  7.893724e+05                                         _Others
# 54    DE       2  9.857267e+05                                         Germany
# 110   KP       2  2.282052e+06           Democratic People's Republic of Korea
# 189   ST       2  2.320998e+06                           Sao Tome and Principe
# 31    BT       2  2.481420e+06                                          Bhutan
# 135   MP       2  4.325148e+06                        Northern Mariana Islands
# 216   VC       2  5.826078e+06                Saint Vincent and the Grenadines
# 57    DM       2  6.075970e+06                                        Dominica
# 117   LC       2  7.678053e+06                                     Saint Lucia
# 50    CW       2  8.780722e+06                                         Curaçao
# 188   SS       2  1.299648e+07                                     South Sudan
# 86    GY       2  1.417064e+07                                          Guyana
# 222   WF       2  1.654063e+07                       Wallis and Futuna Islands
# 219   VI       2  1.683193e+07                    United States Virgin Islands
# 173   RW       2  2.347072e+07                                          Rwanda
# 184   SM       2  2.514325e+07                                      San Marino
# 224   XC       2  2.552754e+07                                         _Others
# 25    BM       2  2.824251e+07                                         Bermuda
# 191   SX       2  3.115379e+07                       Sint Maarten (Dutch part)
# 120   LR       2  3.159825e+07                                         Liberia
# 233   ZW       2  3.355729e+07                                        Zimbabwe
# 218   VG       2  4.107927e+07                          British Virgin Islands
# 187   SR       2  5.656225e+07                                        Suriname
# 127   ME       2  6.136422e+07                                      Montenegro
# 132   MM       2  6.366675e+07                                         Myanmar
# 126   MD       2  8.011399e+07                             Republic of Moldova
# 190   SV       2  8.210143e+07                                     El Salvador
# 106   KH       2  8.409659e+07                                        Cambodia
# 16    BA       2  1.058024e+08                          Bosnia and Herzegovina
# 195   TD       2  1.853774e+08                                            Chad
# 60    EC       2  2.063593e+08                                         Ecuador
# 146   NE       2  2.278940e+08                                           Niger
# 104   KE       2  2.768981e+08                                           Kenya
# 156   PE       2  3.124278e+08                                            Peru
# 23    BJ       2  3.853082e+08                                           Benin
# 227   XS       2  4.093221e+08                                         _Others
# 153   NZ       2  5.448521e+08                                     New Zealand
# 114   KZ       2  7.386522e+08                                      Kazakhstan
# 124   LY       2  8.864510e+08                                           Libya
# 145   NC       2  9.976365e+08                                   New Caledonia
# 209   UA       2  1.303036e+09                                         Ukraine
# 159   PH       2  1.364258e+09                                     Philippines
# 41    CI       2  1.448108e+09                                   Côte d'Ivoire
# 10    AR       2  1.501925e+09                                       Argentina
# 94    IL       2  1.656082e+09                                          Israel
# 207   TW       2  2.229755e+09                                         _Others
# 203   TN       2  4.715403e+09                                         Tunisia
# 111   KR       2  5.043792e+09                               Republic of Korea
# 125   MA       2  5.258472e+09                                         Morocco
# 29    BR       2  5.808726e+09                                          Brazil
# 87    HK       2  6.887024e+09  China, Hong Kong Special Administrative Region
# 179   SG       2  7.631224e+09                                       Singapore
# 103   JP       2  9.259275e+09                                           Japan
# 40    CH       2  1.793014e+10                                     Switzerland
# 212   US       2  3.454441e+10                                   United States

# %%
plt.hist(np.log10(k1_fij.k1_fFRj), 14)
plt.show()

# %% [markdown]
# ## Buyer and seller pareto fits

# %%
df = pd.read_csv('./../../data/processed/_FBCP.csv')

seller_size = df.groupby(['PYOD', 'PERIOD', 'ID'])[['VART']].sum()
buyer_size = df.groupby(['PYOD', 'PERIOD', 'VAT'])[['VART']].sum()

# %%
df.PERIOD.unique()
# Out:
# array([2])

# %%
EU_ctries = df.groupby('PYOD')['VAT'].nunique().sort_values().tail(26).index

seller_TOTsize = df.loc[df.PYOD.isin(EU_ctries)].groupby(['PERIOD', 'ID'])[['VART']].sum()

# %%
x = np.arange(3, 8, .2)

fig, axs = plt.subplots(1, 2, figsize = (16, 5))

# Line of the total
sizes = seller_TOTsize
sizes = pd.DataFrame(np.log10(sizes.loc[2])).rename(columns = {'VART': 'log_size'})

cdf = []
for th in x:
    cdf += [1 - (sizes > th).sum()/len(sizes)]
cdf = np.array(cdf).flatten()
y = np.log10(1 - cdf)
ax = axs[0]
ax.plot(x, y, color = 'k')

for i in range(2):
    ax = axs[i]
    for ctry in EU_ctries:
        sizes = [seller_size, buyer_size][i]
        sizes = pd.DataFrame(np.log10(sizes.loc[ctry].loc[2])).rename(columns = {'VART': 'log_size'})

        if len(sizes) > 10:
            cdf = []
            for th in x:
                cdf += [1 - (sizes > th).sum()/len(sizes)]
            cdf = np.array(cdf).flatten()

            # For what matters, we could just fit a linear in the upper 90% of firms and drop the SMEs. The we would have a pareto/zipf
            y = np.log10(1 - cdf)

            ax.plot(x, y, label = ctry, linestyle = '-', lw = .75)

            ax.set_ylim(-4, 0)
            ax.set_xlim(3, 8)
            ax.set_xlabel('Exporter size (log)', fontsize = 13)
            ax.set_ylabel('log(1 - CDF)', fontsize = 13)
    #         ax.legend(loc = (.1, .1))

            # plt.savefig('./../../../thesis_writing/figures/pareto_option.png', dpi = 400)
plt.show()

# %%
seller_size

x = np.arange(3, 9, .2)

fig, axs = plt.subplots(2, 2, figsize = (16, 10))


# # Line of the total
# sizes = seller_TOTsize
# sizes = pd.DataFrame(np.log10(sizes.loc[2])).rename(columns = {'VART': 'log_size'})
# ax = axs[0]
# ax.plot(x, y, color = 'k')

ctries = np.random.choice(EU_ctries, 10)
for i in range(2):
    ax = axs[i]
    for ctry in ctries:
        side = [seller_size, buyer_size][i]
        slice_ = side.loc[ctry].loc[2]
        sizes = pd.DataFrame(np.log10(slice_)).rename(columns = {'VART': 'log_size'})
#         print(len(sizes))
        # sizes
        hist = slice_.groupby(pd.cut(np.log10(slice_.VART), x))['VART'].agg(['count', 'sum'])
        
#         ax.hist(sizes.log_size, x, alpha = .1, color = '#1f77b4')
        for k, measure in enumerate(['count', 'sum']):
            ax = axs[k][i]
            color = ['#1f77b4', '#ff7f0e'][k]
            ax.fill_between(.5*(x[:-1] + x[1:]), hist[measure], 0, alpha = .1, color = color)
            ax.set_title(['FR sellers', 'Foreign buyers'][i])
            ax.set_yscale('log')
            ax.set_xlabel(['log size in foreign market', 'log size in French market'][i])
            ax.set_ylabel('PDF')
        #     ax.set_ylim(0.0001, 0.5)
            ax.set_xlim(2.5, 10)
    
plt.show()

# %% [markdown]
# ## Bernard Margins

# %%
df = pd.read_csv('./../../data/processed/_FBCP.csv')

firm_sizes = df.groupby(['IMPORT', 'ID', 'PERIOD'])['VART'].sum().reset_index()
df = df.merge(firm_sizes, on = ['IMPORT', 'PERIOD', 'ID'])
df['log_size'] = np.log10(df.VART_y)
# Keep exports
df = df.loc[df.IMPORT == 0].drop('IMPORT', axis = 1)

# %%
grouped = df.groupby(['ID', 'PERIOD'])

n_prods = grouped['CN ID 4'].nunique()
n_vats = grouped['VAT'].nunique()
n_cases = grouped.count().log_size

# %%
data = grouped.first().drop(['CN ID 4','PYOD','VAT','VART_x'], axis = 1)

# %%
data['n_prods'] = n_prods
data['n_vats'] = n_vats
data['n_cases'] = n_cases

data['density'] = n_cases/(n_prods*n_vats)
data['x_mean'] = data.VART_y/n_cases
